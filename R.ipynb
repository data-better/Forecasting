# %% [markdown]
# <a href="https://colab.research.google.com/github/data-better/Forecasting/blob/gh-pages/R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)

# %%
ggplot(data=mpg)+
geom_point(aes(x=displ, y=hwy, color = class))
# Out:
# plot without title

# %%
install.packages("forecast")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’

# %%
library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
url = "https://raw.githubusercontent.com/data-better/Forecasting/gh-pages/data/gdp.csv"
gdp = ts(read.csv(url), start=1970, frequency = 4)

# %%
head(gdp)
# Out:
#         year quarter gdp     gdpsa
# 1970 Q1 1970 1       12807.5 14934.6
# 1970 Q2 1970 2       15732.5 15246.5
# 1970 Q3 1970 3       14621.6 15472.1
# 1970 Q4 1970 4       18689.5 16198.0
# 1971 Q1 1971 1       14512.5 16664.4
# 1971 Q2 1971 2       17709.4 17180.3

# %%
plot(gdp[,3], xlab="", ylab="")
lines(gdp[,4], col=2)
# Out:
# plot without title

# %%
aa = auto.arima(gdp[,3])

# %%
summary(aa)
# Out:
# Series: gdp[, 3]
# ARIMA(2,1,3)(0,1,1)[4]
#
# Coefficients:
#           ar1     ar2     ma1      ma2      ma3     sma1
#       -0.2162  0.6614  0.2574  -0.6778  -0.3240  -0.7059
# s.e.   0.1055  0.1009  0.1128   0.0919   0.0765   0.0623
#
# sigma^2 estimated as 6022037:  log likelihood=-1575.89
# AIC=3165.77   AICc=3166.46   BIC=3187.76
#
# Training set error measures:
#                    ME    RMSE      MAE       MPE     MAPE      MASE
# Training set 284.9973 2376.06 1543.497 0.3695868 1.789295 0.2217755
#                      ACF1
# Training set -0.000805614

# %%
plot(forecast(aa))
# Out:
# Plot with title “Forecasts from ARIMA(2,1,3)(0,1,1)[4]”

# %%
plot(decompose(gdp[,3]))
# Out:
# plot without title
